# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from log_processing import process_log

# %%
log_file = "../backtests/test.log"

trader_data, products_data, activities, trades = process_log(log_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 3
#       1 log_file = "../backtests/test.log"
# ----> 3 trader_data, products_data, activities, trades = process_log(log_file)
#
# File ~/Documents/Projects/RestartedQuants/development/log_processing.py:163, in process_log(file_path)
#     161 sanbox_logs = parse_sandbox_logs(file_path)
#     162 trader_data = extract_trader_data(sanbox_logs)
# --> 163 products_data = extract_product_data(sanbox_logs)
#     164 activities, trades = extract_book_and_trades(file_path)
#     165 return trader_data, products_data, activities, trades
#
# File ~/Documents/Projects/RestartedQuants/development/log_processing.py:105, in extract_product_data(sandbox_logs)
#     103 if key == "order":
#     104     price, volume = value.split("@")
# --> 105     current_product["orders"].append([int(price), int(volume)])
#     106 else:
#     107     if value != "None":
#
# ValueError: invalid literal for int() with base 10: '10002.0'

# %%
rr = products_data["RAINFOREST_RESIN"]

# %%
rr = trades[trades["symbol"] == "RAINFOREST_RESIN"]

# %%
bots = rr[(rr["buyer"] != "SUBMISSION") & (rr["seller"] != "SUBMISSION")]

# %%
bots.reset_index()[:50]
# Out:
#     index  timestamp buyer seller            symbol   currency  price  \
# 0       8       1700               RAINFOREST_RESIN  SEASHELLS  10002
# 1      39       6700               RAINFOREST_RESIN  SEASHELLS  10002
# 2      41       6900               RAINFOREST_RESIN  SEASHELLS  10002
# 3      56      10300               RAINFOREST_RESIN  SEASHELLS   9998
# 4      63      11500               RAINFOREST_RESIN  SEASHELLS  10002
# 5      71      13200               RAINFOREST_RESIN  SEASHELLS   9998
# 6      86      15700               RAINFOREST_RESIN  SEASHELLS  10002
# 7      92      16400               RAINFOREST_RESIN  SEASHELLS  10002
# 8     109      20100               RAINFOREST_RESIN  SEASHELLS  10002
# 9     114      20500               RAINFOREST_RESIN  SEASHELLS   9998
# 10    134      23300               RAINFOREST_RESIN  SEASHELLS   9998
# 11    152      25200               RAINFOREST_RESIN  SEASHELLS  10002
# 12    153      25200               RAINFOREST_RESIN  SEASHELLS   9998
# 13    168      27600               RAINFOREST_RESIN  SEASHELLS   9998
# 14    182      29400               RAINFOREST_RESIN  SEASHELLS  10002
# 15    185      30000               RAINFOREST_RESIN  SEASHELLS   9998
# 16    204      33000               RAINFOREST_RESIN  SEASHELLS  10002
# 17    227      36100               RAINFOREST_RESIN  SEASHELLS  10002
# 18    245      39200               RAINFOREST_RESIN  SEASHELLS   9998
# 19    295      47500               RAINFOREST_RESIN  SEASHELLS  10002
# 20    315      49900               RAINFOREST_RESIN  SEASHELLS   9998
# 21    317      50400               RAINFOREST_RESIN  SEASHELLS   9998
# 22    326      51600               RAINFOREST_RESIN  SEASHELLS  10002
# 23    327      51600               RAINFOREST_RESIN  SEASHELLS  10002
# 24    363      57800               RAINFOREST_RESIN  SEASHELLS   9998
# 25    394      62200               RAINFOREST_RESIN  SEASHELLS  10002
# 26    408      64500               RAINFOREST_RESIN  SEASHELLS   9998
# 27    413      66000               RAINFOREST_RESIN  SEASHELLS   9998
# 28    423      67300               RAINFOREST_RESIN  SEASHELLS   9998
# 29    427      68100               RAINFOREST_RESIN  SEASHELLS   9998
# 30    447      70300               RAINFOREST_RESIN  SEASHELLS   9998
# 31    456      71500               RAINFOREST_RESIN  SEASHELLS  10002
# 32    469      73000               RAINFOREST_RESIN  SEASHELLS  10002
# 33    470      73100               RAINFOREST_RESIN  SEASHELLS  10002
# 34    518      79900               RAINFOREST_RESIN  SEASHELLS   9998
# 35    552      86700               RAINFOREST_RESIN  SEASHELLS   9998
# 36    570      89200               RAINFOREST_RESIN  SEASHELLS  10002
# 37    577      90000               RAINFOREST_RESIN  SEASHELLS   9998
# 38    578      90000               RAINFOREST_RESIN  SEASHELLS   9998
# 39    579      90100               RAINFOREST_RESIN  SEASHELLS  10002
# 40    580      90300               RAINFOREST_RESIN  SEASHELLS   9998
# 41    602      92700               RAINFOREST_RESIN  SEASHELLS  10002
# 42    616      94200               RAINFOREST_RESIN  SEASHELLS  10002
# 43    620      94600               RAINFOREST_RESIN  SEASHELLS   9998
# 44    661     100200               RAINFOREST_RESIN  SEASHELLS   9998
# 45    673     101500               RAINFOREST_RESIN  SEASHELLS   9998
# 46    680     102300               RAINFOREST_RESIN  SEASHELLS   9998
# 47    682     102600               RAINFOREST_RESIN  SEASHELLS   9998
# 48    683     102600               RAINFOREST_RESIN  SEASHELLS   9998
# 49    686     103400               RAINFOREST_RESIN  SEASHELLS  10002
#
#     quantity
# 0          1
# 1          3
# 2          1
# 3          1
# 4          2
# 5          2
# 6          1
# 7          1
# 8          4
# 9          1
# 10         1
# 11         1
# 12         3
# 13         4
# 14         1
# 15         1
# 16         6
# 17         1
# 18         1
# 19         4
# 20         6
# 21         1
# 22         1
# 23         1
# 24         1
# 25         4
# 26         1
# 27         1
# 28         5
# 29         2
# 30         2
# 31         3
# 32         1
# 33         1
# 34         3
# 35         1
# 36         1
# 37         1
# 38         1
# 39         3
# 40         1
# 41         2
# 42         1
# 43         1
# 44         1
# 45         3
# 46         4
# 47         2
# 48         1
# 49         1
